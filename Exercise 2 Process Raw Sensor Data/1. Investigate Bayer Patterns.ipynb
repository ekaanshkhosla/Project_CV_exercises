# %%
import numpy as np

# %%
im1 = np.load('IMG_9939.npy')

# %%
im1.shape
# Out:
# (4014, 6020)

# %%
im1
# Out:
# array([[3361, 2596, 3352, ..., 2642, 3489, 2619],
#        [2829, 3371, 2854, ..., 3476, 2880, 3488],
#        [3382, 2614, 3380, ..., 2665, 3452, 2641],
#        ...,
#        [2826, 3464, 2878, ..., 3104, 2638, 3122],
#        [3453, 2671, 3453, ..., 2540, 3121, 2555],
#        [2837, 3484, 2830, ..., 3104, 2643, 3148]], dtype=uint16)

# %% [markdown]
# ### EDA of Image Data

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the raw sensor data
raw_data = np.load('IMG_9939.npy')

# Display the raw data to get an idea of its structure
plt.imshow(raw_data, cmap='gray')
plt.title('Raw Sensor Data')
plt.show()

# %%
def inspect_bayer_pattern(raw_data):
    # Visualize a small part of the raw data
    plt.imshow(raw_data[:10, :10], cmap='gray')
    plt.title('Zoomed-in Raw Data')
    plt.show()
    # Add more sophisticated analysis as needed

raw_data = np.load('IMG_9939.npy')
inspect_bayer_pattern(raw_data)

# %%
# import plotly.express as px
# from skimage import io
# img = io.imread('IMG_9939.jpg')
# fig = px.imshow(img)
# fig.show()

# %% [markdown]
# ### Remove below comment to find the x, y coordinates in the picture

# %%
# import plotly.express as px
# import numpy as np
# img = np.load('IMG_9939.npy')
# fig = px.imshow(img, color_continuous_scale='gray')
# fig.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def inspect_bayer_pattern(raw_data):
    # Visualize a small part of the raw data
    plt.imshow(raw_data[2500:3000, 1000:3000], cmap='gray')
    plt.title('Zoomed-in Raw Data')
    plt.show()
    # Add more sophisticated analysis as needed

raw_data = np.load('IMG_9939.npy')
inspect_bayer_pattern(raw_data)

# %% [markdown]
# ### Analyzing Blue

# %%
import numpy as np
import matplotlib.pyplot as plt

def inspect_bayer_pattern(raw_data):
    # Visualize a small part of the raw data
    plt.imshow(raw_data[2660:2670, 1860:1870], cmap='gray')
    plt.title('Zoomed-in Raw Data')
    plt.show()
    # Add more sophisticated analysis as needed

raw_data = np.load('IMG_9939.npy')
inspect_bayer_pattern(raw_data)

# %% [markdown]
# ### Analyzing Green

# %%
import numpy as np
import matplotlib.pyplot as plt

def inspect_bayer_pattern(raw_data):
    # Visualize a small part of the raw data
    plt.imshow(raw_data[1960:1970, 1940:1950], cmap='gray')
    plt.title('Zoomed-in Raw Data')
    plt.show()
    # Add more sophisticated analysis as needed
    
raw_data = np.load('IMG_9939.npy')
inspect_bayer_pattern(raw_data)

# %% [markdown]
# ### Analyzing Red

# %%
import numpy as np
import matplotlib.pyplot as plt

def inspect_bayer_pattern(raw_data):
    # Visualize a small part of the raw data
    plt.imshow(raw_data[1410:1420, 2090:2100], cmap='gray')
    plt.title('Zoomed-in Raw Data')
    plt.show()
    # Add more sophisticated analysis as needed
    
raw_data = np.load('IMG_9939.npy')
inspect_bayer_pattern(raw_data)

# %%
print("The Bayer filter is like:-")
print("G B G B")
print("R G R G")
print("G B R G")
print("R G R G")
# Out:
# The Bayer filter is like:-
# G B G B
# R G R G
# G B R G
# R G R G
